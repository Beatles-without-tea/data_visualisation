# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
def clean_and_convert(string):
    # remove commas and dollar signs
    string = string.replace(',', '').replace('$', '')

    # convert to float
    number = float(string)

    return number

# %%
data
# Out:
# review_scores_cleanliness    4.75
# dtype: float64

# %%
ext_listing.groupby('neighbourhood_cleansed')[review_type_choice].median()
# Out:
# neighbourhood_cleansed
# Batignolles-Monceau    4.73
# Bourse                 4.69
# Buttes-Chaumont        4.74
# Buttes-Montmartre      4.75
# Entrepôt               4.73
# Gobelins               4.71
# Hôtel-de-Ville         4.75
# Louvre                 4.75
# Luxembourg             4.72
# Ménilmontant           4.75
# Observatoire           4.72
# Opéra                  4.76
# Palais-Bourbon         4.77
# Panthéon               4.73
# Passy                  4.75
# Popincourt             4.73
# Reuilly                4.75
# Temple                 4.74
# Vaugirard              4.75
# Élysée                 4.75
# Name: review_scores_cleanliness, dtype: float64

# %%
df_1 = ext_listing.iloc[:len(ext_listing)//2]  # First half
df_2 = ext_listing.iloc[len(ext_listing)//2:]  # Second half

# %%
df_1.to_csv('listings_ext_first_half.csv', index=False)
df_2.to_csv('listings_ext_second_half.csv', index=False)

# %%
df_1 = pd.read_csv('listings_ext_first_half.csv')
df_2 = pd.read_csv('listings_ext_second_half.csv')

ext_listing = pd.concat([df_1, df_2])
# Out:
# /var/folders/n_/lmz09xv942jc4f7l1r3x_j140000gn/T/ipykernel_58862/2137810093.py:1: DtypeWarning: Columns (2,22,41,45,46) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_1 = pd.read_csv('listings_ext_first_half.csv')
# /var/folders/n_/lmz09xv942jc4f7l1r3x_j140000gn/T/ipykernel_58862/2137810093.py:2: DtypeWarning: Columns (2,22,41,45,46) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_2 = pd.read_csv('listings_ext_second_half.csv')

# %%
ext_listing
# Out:
#                  id                                      listing_url  \
# 0      5.396000e+03                https://www.airbnb.com/rooms/5396
# 1      7.397000e+03                https://www.airbnb.com/rooms/7397
# 2      7.964000e+03                https://www.airbnb.com/rooms/7964
# 3      9.359000e+03                https://www.airbnb.com/rooms/9359
# 4      9.952000e+03                https://www.airbnb.com/rooms/9952
# ...             ...                                              ...
# 28359  8.432640e+17  https://www.airbnb.com/rooms/843263965560420069
# 28360  8.432641e+17  https://www.airbnb.com/rooms/843264086459366855
# 28361  8.432688e+17  https://www.airbnb.com/rooms/843268818718844445
# 28362  8.432702e+17  https://www.airbnb.com/rooms/843270207995447181
# 28363  8.432729e+17  https://www.airbnb.com/rooms/843272911371318203
#
#             scrape_id last_scraped       source  \
# 0      20230313171257   2023-03-14  city scrape
# ...

# %%
ext_listing.loc[ext_listing['neighbourhood_cleansed']==review_location_choice, ['neighbourhood_cleansed',review_type_choice]]
# Out:
#       neighbourhood_cleansed  review_scores_cleanliness
# 0             Hôtel-de-Ville                       4.51
# 1             Hôtel-de-Ville                       4.44
# 54            Hôtel-de-Ville                       4.74
# 77            Hôtel-de-Ville                       4.88
# 81            Hôtel-de-Ville                       4.93
# ...                      ...                        ...
# 56441         Hôtel-de-Ville                        NaN
# 56461         Hôtel-de-Ville                        NaN
# 56540         Hôtel-de-Ville                        NaN
# 56546         Hôtel-de-Ville                        NaN
# 56723         Hôtel-de-Ville                        NaN
#
# [1922 rows x 2 columns]

# %%
import folium
review_location_choice = 'Hôtel-de-Ville'
review_type_choice = 'review_scores_cleanliness'
data = ext_listing.loc[ext_listing['neighbourhood_cleansed']==review_location_choice, ['neighbourhood_cleansed',review_type_choice]]

# Create a map centered on Paris
m = folium.Map(location=[48.8566, 2.3522], zoom_start=12, width='100%', height='100%')
# Add a choropleth layer to the map to show price by neighborhood
folium.Choropleth(
    geo_data='data/neighbourhoods.geojson',
    name='choropleth',
    data=data,
    columns=['neighbourhood', 'price'],
    key_on='feature.properties.neighbourhood',
    fill_color='YlOrRd',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Average price by night',
    tooltip = folium.GeoJsonTooltip(fields=['neighbourhood', 'price'], sticky=True, labels=True, toLocaleString=True)

).add_to(m)

# Add a layer control to the map
folium.LayerControl().add_to(m)
# Out:
# /var/folders/n_/lmz09xv942jc4f7l1r3x_j140000gn/T/ipykernel_58862/810303980.py:4: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data = ext_listing.loc[ext_listing['neighbourhood_cleansed']==review_location_choice, ['neighbourhood_cleansed',review_type_choice]].median()

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
ext_listing['neighbourhood_cleansed'].unique()
# Out:
# array(['Hôtel-de-Ville', 'Opéra', 'Louvre', 'Popincourt',
#        'Buttes-Montmartre', 'Luxembourg', 'Gobelins', 'Entrepôt',
#        'Batignolles-Monceau', 'Temple', 'Buttes-Chaumont', 'Bourse',
#        'Ménilmontant', 'Observatoire', 'Panthéon', 'Vaugirard', 'Élysée',
#        'Reuilly', 'Passy', 'Palais-Bourbon'], dtype=object)

# %%
ext_listing = pd.read_csv('data/listings_ext.csv')

# %%
ext_listing['price']
# Out:
# 0        $124.00
# 1        $130.00
# 2        $140.00
# 3         $75.00
# 4        $160.00
#           ...
# 56721    $640.00
# 56722    $538.00
# 56723    $600.00
# 56724    $181.00
# 56725    $300.00
# Name: price, Length: 56726, dtype: object

# %%
ext_listing['price'] = ext_listing['price'].apply(clean_and_convert)

# %%
grouped = ext_listing.groupby(['neighbourhood_cleansed','property_type'])['price'].median()
grouped = grouped.unstack() # This will pivot your property_type to columns

# Now plot
grouped.plot(kind='barh', stacked=False, width=2)
plt.ylabel('Median Price')
plt.title('Median Price by Neighbourhood and Property Type')
plt.show()
